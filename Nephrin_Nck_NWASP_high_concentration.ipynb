# %% [markdown]
# ## Higher concentrations of Nephrin, Nck and NWASP produce large clusters. This bifurcated cluster size distribution is an indication of phase transition.

# %%
# Package import
from molclustpy import *

# %%
# bngl file (BioNetGen model) 
bng_file = 'Nephrin_Nck_NWASP_high_concentration.bngl'

# Initialization of the Simulation Object
simObj = BNG_multiTrials(bng_file, t_end=0.02, steps=20, numRuns=20)
print(simObj)
simObj.runTrials(delSim=False)
print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 # Initialization of the Simulation Object
#       5 simObj = BNG_multiTrials(bng_file, t_end=0.02, steps=20, numRuns=20)
# ----> 6 print(simObj)
#       7 simObj.runTrials(delSim=False)
#       8 print()
#
# File ~\anaconda3\envs\molenv\lib\site-packages\molclustpy\MultiRun_BNG.py:32, in BNG_multiTrials.__repr__(self)
#      30 def __repr__(self):
#      31     info = f"\n***** // ***** \nClass : {self.__class__.__name__}\nFile Path : {self.infile}\n\nt_end : {self.t_end} seconds \t output_steps : {self.steps}\nNumber of runs: {self.numRuns}\n"
# ---> 32     names, numSite, counts, ComplexIC = self.getMolecules()
#      33     info = info + f'\nMolecules: {names}\nNumber of binding sites: {numSite}\nSpecies Counts: {counts}\n'
#      34     if ComplexIC:
#
# File ~\anaconda3\envs\molenv\lib\site-packages\molclustpy\MultiRun_BNG.py:81, in BNG_multiTrials.getMolecules(self)
#      79 names, vals, counts = [], [], [] # Molecular names, valency (number of binding sites) and counts
#      80 IsComplexIC = False # Is there any multi-molecular species at the initial condition ?
# ---> 81 model = bionetgen.bngmodel(self.infile)
#      82 params = model.parameters
#      83 molecules = model.molecule_types
#
# File ~\anaconda3\envs\molenv\lib\site-packages\bionetgen\modelapi\model.py:98, in bngmodel.__init__(self, bngl_model, BNGPATH, generate_network, suppress)
#      94 self.model_path = bngl_model
#      95 self.bngparser = BNGParser(
#      96     bngl_model, generate_network=generate_network, suppress=True
#      97 )
# ---> 98 self.bngparser.parse_model(self)
#      99 for block in self._block_order:
#     100     if block not in self.active_blocks:
#
# File ~\anaconda3\envs\molenv\lib\site-packages\bionetgen\modelapi\bngparser.py:64, in BNGParser.parse_model(self, model_obj)
#      59 def parse_model(self, model_obj) -> None:
#      60     """
#      61     Will determine the parser route eventually and call the right
#      62     parser
#      63     """
# ---> 64     self._parse_model_bngpl(model_obj)
#      65     if self.to_parse_actions:
#      66         self.parse_actions(model_obj)
#
# File ~\anaconda3\envs\molenv\lib\site-packages\bionetgen\modelapi\bngparser.py:82, in BNGParser._parse_model_bngpl(self, model_obj)
#      78 if model_file.endswith(".bngl"):
#      79     # TODO: Add verbosity option to the library
#      80     # print("Attempting to generate XML")
#      81     with TemporaryFile("w+") as xml_file:
# ---> 82         if self.bngfile.generate_xml(xml_file):
#      83             # TODO: Add verbosity option to the library
#      84             xmlstr = xml_file.read()
#      85             # < is not a valid XML character, we need to replace it
#
# File ~\anaconda3\envs\molenv\lib\site-packages\bionetgen\modelapi\bngfile.py:67, in BNGFile.generate_xml(self, xml_file, model_file)
#      64 # temporary folder to work in
#      65 with TemporaryDirectory() as temp_folder:
#      66     # make a stripped copy without actions in the folder
# ---> 67     stripped_bngl = self.strip_actions(model_file, temp_folder)
#      68     # run with --xml
#      69     os.chdir(temp_folder)
#
# File ~\anaconda3\envs\molenv\lib\site-packages\bionetgen\modelapi\bngfile.py:108, in BNGFile.strip_actions(self, model_path, folder)
#     106 path, model_file = os.path.split(model_path)
#     107 # open model and strip actions
# --> 108 with open(model_path, "r", encoding="UTF-8") as mf:
#     109     # read and strip actions
#     110     mstr = mf.read()
#     111     # TODO: Clean this up _a lot_
#     112     # this removes any new line escapes (\ \n) to continue
#     113     # to another line, so we can just remove the action lines
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Nephrin_Nck_NWASP_high_concentration.bngl'

# %%
# analyze data across multiple trials
outpath = simObj.getOutPath()
molecules, numSite, counts, _ = simObj.getMolecules()
nfsObj = NFSim_output_analyzer(outpath)
print(nfsObj)
nfsObj.process_gdatfiles()
nfsObj.process_speciesfiles(molecules, counts, numSite)

# %%
# Visualization
# indexList for observables
plotTimeCourse(outpath, obsList=[2,4,6])
plotTimeCourse(outpath, obsList=[10,11])

# %%
# 2A: Cluster size distribution (ACO: Average Cluster Occupancy)
plotClusterDist(outpath)
# Binned distribution by providing cluster size ranges
plotClusterDist(outpath, sizeRange=[1,10,100])

# %%
# 2B: Number of bonds per molecule
plotBondsPerMolecule(outpath)

# %%
# 2C: Bound fraction distribution
plotBoundFraction(outpath)

# %%
# 3A. Average composition of indivual clusters. 
# Default is all the clusters present in the system. As before, adjust width and transparency (alpha) for visual clarity.
plotClusterComposition(outpath, specialClusters=[], width=0.15, alpha=0.5)

# You can look at the composition of a set of clusters (specialClusters) also
plotClusterComposition(outpath, specialClusters=[2, 4, 10], width=0.15, alpha=0.7)

plotClusterComposition(outpath, specialClusters=[580, 587], width=0.15, alpha=0.7)

# %%
# 3B. Bondcount distribution of each molecular type 
# plotBondCounts(outpath, molecules=molecules) # Reading molecules from previous block

# You may provide a subset of molecules also
plotBondCounts(outpath, molecules=['Nck'])
